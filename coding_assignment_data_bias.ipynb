# %% [markdown]
# Project Aim: Analyzing the Perspective model on the basis of fairness and bias.

# %% [markdown]
# Hypothesis: The Perspective model is religiously biased, that is, it is unfair towards certain religions.

# %% [markdown]
# Using the Perspective model to get toxicity scores on 20 sample statements (5 Islam-themed toxic comments, 5 Islam-themed non-toxic comment, 5 Buddhism-themed toxic comments, 5 Buddhism-themed non-toxic comments).

# %%
from googleapiclient import discovery
import json

API_KEY = 'AIzaSyDde0t1MECgxs2-9YmA_6XfXzbIZURjcQA'

client = discovery.build(
  "commentanalyzer",
  "v1alpha1",
  developerKey="AIzaSyDde0t1MECgxs2-9YmA_6XfXzbIZURjcQA",
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  static_discovery=False,
)

analyze_request = {
  'comment': { 'text': 'sample text' },
  'requestedAttributes': {'TOXICITY': {}}
}

response = client.comments().analyze(body=analyze_request).execute()
print(json.dumps(response, indent=2))
# Out:
# {
#   "attributeScores": {
#     "TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 11,
#           "score": {
#             "value": 0.013885498,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.013885498,
#         "type": "PROBABILITY"
#       }
#     }
#   },
#   "languages": [
#     "en"
#   ],
#   "detectedLanguages": [
#     "en"
#   ]
# }

# %% [markdown]
# Transforming the excel spreadsheet with the sample comments, expected value, perspective score, and perspective predicted value into a dataframe.

# %%
import pandas as pd
df = pd.read_csv("coding_assignment_data_bias.csv")
df
# Out:
#                          Type of Statement Expected Value  \
# 0          Toxic sentences targeting Islam          Toxic
# 1          Toxic sentences targeting Islam          Toxic
# 2          Toxic sentences targeting Islam          Toxic
# 3          Toxic sentences targeting Islam          Toxic
# 4          Toxic sentences targeting Islam          Toxic
# 5      Non-Toxic Sentences Targeting Islam      Non-Toxic
# 6      Non-Toxic Sentences Targeting Islam      Non-Toxic
# 7      Non-Toxic Sentences Targeting Islam      Non-Toxic
# 8      Non-Toxic Sentences Targeting Islam      Non-Toxic
# 9      Non-Toxic Sentences Targeting Islam      Non-Toxic
# 10      Toxic Sentences Targeting Buddhism          Toxic
# 11      Toxic Sentences Targeting Buddhism          Toxic
# 12      Toxic Sentences Targeting Buddhism          Toxic
# 13      Toxic Sentences Targeting Buddhism          Toxic
# 14      Toxic Sentences Targeting Buddhism          Toxic
# ...

# %% [markdown]
# Results:

# %% [markdown]
# Class-wise accuracy for toxic and non-toxic comments:

# %%
toxic_accuracy = sum((df['Expected Value'] == 'Toxic') & (df['Predicted Value'] == 'Toxic')) / sum(df['Expected Value'] == 'Toxic')
non_toxic_accuracy = sum((df['Expected Value'] == 'Non-Toxic') & (df['Predicted Value'] == 'Non-Toxic')) / sum(df['Expected Value'] == 'Non-Toxic')

print(f"The accuracy for toxic comments is {toxic_accuracy:.2%}")
print(f"The accuracy for non toxic comments is {non_toxic_accuracy:.2%}")
# Out:
# The accuracy for toxic comments is 60.00%
# The accuracy for non toxic comments is 100.00%

# %% [markdown]
# Religion-wise accuracy for comments:

# %%
islam_accuracy = sum((df['Predicted Value'][:10] == df['Expected Value'][:10])) / len(df['Predicted Value'][:10])
buddhism_accuracy = sum((df['Predicted Value'][10:] == df['Expected Value'][10:])) / len(df['Predicted Value'][10:])

print(f"The accuracy for Islam-themed comments is {islam_accuracy:.2%}")
print(f"The accuracy for Buddhism-themed comments is {buddhism_accuracy:.2%}")
# Out:
# The accuracy for Islam-themed comments is 90.00%
# The accuracy for Buddhism-themed comments is 70.00%

# %% [markdown]
# Religion-wise and class-wise accuracy for comments:

# %%
islam_toxic_accuracy = sum((df['Expected Value'][:5] == 'Toxic') & (df['Predicted Value'][:5] == 'Toxic')) / len(df['Expected Value'][:5])
islam_non_toxic_accuracy = sum((df['Expected Value'][5:10] == 'Non-Toxic') & (df['Predicted Value'][5:10] == 'Non-Toxic')) / len(df['Expected Value'][5:10])

buddhism_toxic_accuracy = sum((df['Expected Value'][10:15] == 'Toxic') & (df['Predicted Value'][10:15] == 'Toxic')) / len(df['Expected Value'][10:15])
buddhism_non_toxic_accuracy = sum((df['Expected Value'][15:20] == 'Non-Toxic') & (df['Predicted Value'][15:20] == 'Non-Toxic')) / len(df['Expected Value'][15:20])

print(f"The accuracy for Islam-themed toxic comments is {islam_toxic_accuracy:.2%}")
print(f"The accuracy for Islam-themed non-toxic comments is {islam_non_toxic_accuracy:.2%}")
print(f"The accuracy for Buddhism-themed toxic comments is {buddhism_toxic_accuracy:.2%}")
print(f"The accuracy for Buddhism-themed non-toxic comments is {buddhism_non_toxic_accuracy:.2%}")
# Out:
# The accuracy for Islam-themed toxic comments is 80.00%
# The accuracy for Islam-themed non-toxic comments is 100.00%
# The accuracy for Buddhism-themed toxic comments is 40.00%
# The accuracy for Buddhism-themed non-toxic comments is 100.00%

# %% [markdown]
# Analysis of the results: The results prove the hypothesis right, because the toxicity accuracy for Islam-themed comments is 20 percent more than that for Buddhist comments. Although, the accuracy for non-toxic comments of both religions is 100%, the accuracy for Islam-themed toxic comments is 40% more than that for Buddhist-themed toxic comments.

# %% [markdown]
# Potential explanation for the bias: In my opinion the overall higher population of Muslims than Buddhists and the higher prevalance of Islamophobic comments result in the machine learning model being biased.
